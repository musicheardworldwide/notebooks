# %% [markdown]
# <a href="https://colab.research.google.com/github/musicheardworldwide/notebooks/blob/main/deepseek_training_dolphin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: download this dataset https://huggingface.co/datasets/cognitivecomputations/dolphin-r1

# !pip install datasets

from datasets import load_dataset

dataset = load_dataset("cognitivecomputations/dolphin-r1", "reasoning-deepseek")
dataset
# Out:
# ...
# dolphin-r1-reasoning-deepseek.jsonl:   0%|          | 0.00/3.85G [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/300018 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['messages', 'reasoning', 'answer', 'model'],
#         num_rows: 300018
#     })
# })
